# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data_path = "C:\\Users\\Saranya.Sakkarapani\\solar_data\\train_data\\train.csv"
df_train = pd.read_csv(train_data_path)

# %%
test_data_path = "C:\\Users\\Saranya.Sakkarapani\\solar_data\\test_data\\test.csv"
df_test = pd.read_csv(test_data_path)

# %% [markdown]
# # EDA

# %%
df_train
# Out:
#                   Timestamp  Temperature  Dew Point  Surface Albedo  Pressure  \
# 0       2019-01-01 00:00:00         12.5        6.9            0.21      1005
# 1       2019-01-01 00:10:00         12.3        6.9            0.21      1005
# 2       2019-01-01 00:20:00         12.1        6.9            0.21      1005
# 3       2019-01-01 00:30:00         12.0        6.9            0.21      1005
# 4       2019-01-01 00:40:00         11.8        6.9            0.21      1005
# ...                     ...          ...        ...             ...       ...
# 210235  2022-12-31 23:10:00          6.9        5.8            0.21      1009
# 210236  2022-12-31 23:20:00          6.8        5.8            0.21      1009
# 210237  2022-12-31 23:30:00          6.8        5.8            0.21      1009
# 210238  2022-12-31 23:40:00          6.8        5.6            0.21      1009
# 210239  2022-12-31 23:50:00          6.8        5.6            0.21      1009
#
#         Wind Direction  Wind Speed  Clearsky DHI  Clearsky DNI  Clearsky GHI  \
# 0                  121         1.0             0             0             0
# 1                  122         1.0             0             0             0
# 2                  124         1.0             0             0             0
# 3                  125         1.0             0             0             0
# 4                  126         1.0             0             0             0
# ...                ...         ...           ...           ...           ...
# 210235              54         1.2             0             0             0
# 210236              54         1.2             0             0             0
# 210237              55         1.1             0             0             0
# 210238              55         1.1             0             0             0
# 210239              56         1.1             0             0             0
#
#         Fill Flag  Ozone  Cloud Type  Solar Zenith Angle  Precipitable Water  \
# 0               0  0.258           1              173.92                 1.4
# 1               0  0.258           1              171.79                 1.3
# 2               0  0.258           1              169.59                 1.3
# 3               0  0.258           1              167.37                 1.3
# 4               0  0.258           1              165.13                 1.3
# ...           ...    ...         ...                 ...                 ...
# 210235          0  0.279           4              173.77                 1.8
# 210236          0  0.279           7              175.77                 1.8
# 210237          0  0.279           7              177.31                 1.8
# 210238          0  0.279           7              177.36                 1.8
# 210239          0  0.280           7              175.87                 1.8
#
#         Relative Humidity
# 0                   68.82
# 1                   69.73
# 2                   70.65
# 3                   71.11
# 4                   71.91
# ...                   ...
# 210235              92.63
# 210236              93.26
# 210237              93.26
# 210238              91.95
# 210239              91.95
#
# [210240 rows x 16 columns]

# %%
df_train.shape
# Out:
# (210240, 16)

# %%
df_train['Timestamp'] = pd.to_datetime(df_train['Timestamp'], format='%Y-%m-%d %H:%M:%S')

# %%
df_train.dtypes
# Out:
# Timestamp              object
# Temperature           float64
# Dew Point             float64
# Surface Albedo        float64
# Pressure                int64
# Wind Direction          int64
# Wind Speed            float64
# Clearsky DHI            int64
# Clearsky DNI            int64
# Clearsky GHI            int64
# Fill Flag               int64
# Ozone                 float64
# Cloud Type              int64
# Solar Zenith Angle    float64
# Precipitable Water    float64
# Relative Humidity     float64
# dtype: object

# %%
feature_cols = ['Cloud Type','Dew Point','Temperature','Pressure','Relative Humidity','Ozone','Solar Zenith Angle','Surface Albedo','Precipitable Water','Wind Direction','Wind Speed','Fill Flag']

for col in feature_cols:
    print(col)
    plt.figure(figsize=(15, 5))
    df_train[col].plot()
    plt.show()
# Out:
# Cloud Type
# Dew Point
# Temperature
# Pressure
# Relative Humidity
# Ozone
# Solar Zenith Angle
# Surface Albedo
# Precipitable Water
# Wind Direction
# Wind Speed
# Fill Flag

# %% [markdown]
# # Heatmap Analysis

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(df_train.corr().abs(), annot=True)
plt.show()

# %%
target_cols = ['Clearsky DHI', 'Clearsky DNI', 'Clearsky GHI']
plt.figure(figsize=(12, 10))
sns.heatmap(df_train.corr()[target_cols].drop(target_cols).sort_values(target_cols, ascending=False), annot=True)
plt.show()

# %% [markdown]
# # Calculating GHI

# %%
df_train['GHI_cal'] = df_train['Clearsky DNI']*np.cos(np.radians(df_train['Solar Zenith Angle'])) + df_train['Clearsky DHI']

# %%
df_train
# Out:
#                  Timestamp  Temperature  Dew Point  Surface Albedo  Pressure  \
# 0      2019-01-01 00:00:00         12.5        6.9            0.21      1005
# 1      2019-01-01 00:10:00         12.3        6.9            0.21      1005
# 2      2019-01-01 00:20:00         12.1        6.9            0.21      1005
# 3      2019-01-01 00:30:00         12.0        6.9            0.21      1005
# 4      2019-01-01 00:40:00         11.8        6.9            0.21      1005
# ...                    ...          ...        ...             ...       ...
# 210235 2022-12-31 23:10:00          6.9        5.8            0.21      1009
# 210236 2022-12-31 23:20:00          6.8        5.8            0.21      1009
# 210237 2022-12-31 23:30:00          6.8        5.8            0.21      1009
# 210238 2022-12-31 23:40:00          6.8        5.6            0.21      1009
# 210239 2022-12-31 23:50:00          6.8        5.6            0.21      1009
#
#         Wind Direction  Wind Speed  Clearsky DHI  Clearsky DNI  Clearsky GHI  \
# 0                  121         1.0             0             0             0
# 1                  122         1.0             0             0             0
# 2                  124         1.0             0             0             0
# 3                  125         1.0             0             0             0
# 4                  126         1.0             0             0             0
# ...                ...         ...           ...           ...           ...
# 210235              54         1.2             0             0             0
# 210236              54         1.2             0             0             0
# 210237              55         1.1             0             0             0
# 210238              55         1.1             0             0             0
# 210239              56         1.1             0             0             0
#
#         Fill Flag  Ozone  Cloud Type  Solar Zenith Angle  Precipitable Water  \
# 0               0  0.258           1              173.92                 1.4
# 1               0  0.258           1              171.79                 1.3
# 2               0  0.258           1              169.59                 1.3
# 3               0  0.258           1              167.37                 1.3
# 4               0  0.258           1              165.13                 1.3
# ...           ...    ...         ...                 ...                 ...
# 210235          0  0.279           4              173.77                 1.8
# 210236          0  0.279           7              175.77                 1.8
# 210237          0  0.279           7              177.31                 1.8
# 210238          0  0.279           7              177.36                 1.8
# 210239          0  0.280           7              175.87                 1.8
#
#         Relative Humidity  GHI_cal
# 0                   68.82      0.0
# 1                   69.73      0.0
# 2                   70.65      0.0
# 3                   71.11      0.0
# 4                   71.91      0.0
# ...                   ...      ...
# 210235              92.63      0.0
# 210236              93.26      0.0
# 210237              93.26      0.0
# 210238              91.95      0.0
# 210239              91.95      0.0
#
# [210240 rows x 17 columns]

# %% [markdown]
# # Heatmap with GHI

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(20,20))
plt.title('Pearson Correlation of Features')
sns.heatmap(df_train.corr(), square=True, cmap=colormap, annot=True)
# Out:
# <AxesSubplot:title={'center':'Pearson Correlation of Features'}>

# %% [markdown]
# GHI, DNI, DHI have high correlation with Solar Zenith Angle.<br>
# Moderate Correlation Temperature & Wind Speed.<br>
# Temperature has high correlation with pressure & surface albedo and moderate correlaton with Precipitable Water.<br>
# Precipitable Water has High correlation with Dew Point & Pressure and moderately correlated with relative humidity, cloud type.

# %% [markdown]
# # GHI and TIME plot

# %%
from matplotlib import dates as mpl_dates

# %%
plt.plot(df_train['Timestamp'][0:125], df_train['Clearsky GHI'][0:125])
plt.title('GHI vs Time')
plt.xlabel('Date')
plt.ylabel('GHI')
plt.gcf().autofmt_xdate()
date_format = mpl_dates.DateFormatter('%M %H, %d %b %Y')
plt.gca().xaxis.set_major_formatter(date_format)
plt.tight_layout()
plt.show()

# %%
df_train.describe()
# Out:
#          Temperature      Dew Point  Surface Albedo       Pressure  \
# count  210240.000000  210240.000000   210240.000000  210240.000000
# mean       26.795495      13.447805        0.211623     996.856141
# std         8.639162      10.234861        0.020889       7.226820
# min         1.000000     -12.400000        0.170000     978.000000
# 25%        20.800000       4.900000        0.200000     990.000000
# 50%        27.300000      13.100000        0.200000     997.000000
# 75%        32.200000      24.400000        0.230000    1003.000000
# max        48.900000      29.100000        0.260000    1013.000000
#
#        Wind Direction     Wind Speed   Clearsky DHI   Clearsky DNI  \
# count   210240.000000  210240.000000  210240.000000  210240.000000
# mean       209.095453       1.918037      96.720681     225.098992
# std        101.616108       1.194954     120.334380     277.920322
# min          0.000000       0.000000       0.000000       0.000000
# 25%        109.000000       1.100000       0.000000       0.000000
# 50%        248.000000       1.500000       0.000000       0.000000
# 75%        293.000000       2.500000     194.000000     486.000000
# max        360.000000       9.500000     603.000000    1008.000000
#
#         Clearsky GHI      Fill Flag          Ozone     Cloud Type  \
# count  210240.000000  210240.000000  210240.000000  210240.000000
# mean      249.938537       0.288699       0.268813       2.513604
# std       325.049751       1.052178       0.015632       3.093565
# min         0.000000       0.000000       0.217000       0.000000
# 25%         0.000000       0.000000       0.259000       0.000000
# 50%         0.000000       0.000000       0.270000       1.000000
# 75%       533.000000       0.000000       0.279000       6.000000
# max      1053.000000       5.000000       0.351000       9.000000
#
#        Solar Zenith Angle  Precipitable Water  Relative Humidity  \
# count       210240.000000       210240.000000      210240.000000
# mean            89.745758            3.377582          53.364443
# std             42.852632            2.261960          29.692608
# min              2.210000            0.300000           4.100000
# 25%             53.140000            1.500000          25.540000
# 50%             89.400000            2.500000          51.210000
# 75%            126.440000            5.700000          80.820000
# max            177.950000            8.900000         100.000000
#
#              GHI_cal
# count  210240.000000
# mean      249.938980
# std       325.049633
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       533.435489
# max      1054.021274

# %%
df_train['Timestamp'] = pd.to_datetime(df_train['Timestamp'], format='%Y-%m-%d %H:%M:%S')

# %% [markdown]
# # Extracting values from Timestamp

# %%
df_train["DAY"] = pd.to_datetime(df_train["Timestamp"]).dt.day_name()
df_train["MONTH"] = pd.to_datetime(df_train["Timestamp"]).dt.month
df_train["WEEK"] = pd.to_datetime(df_train["Timestamp"]).dt.week
# Out:
# C:\Users\Saranya.Sakkarapani\AppData\Local\Temp\ipykernel_17976\2576400166.py:3: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df_train["WEEK"] = pd.to_datetime(df_train["Timestamp"]).dt.week

# %%
from sklearn import preprocessing
  
# label_encoder object knows 
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'day'.
df_train['DAY']= label_encoder.fit_transform(df_train['DAY'])
  
df_train['DAY'].unique()
# Out:
# array([5, 6, 4, 0, 2, 3, 1])

# %%
df_train["DATE"] = pd.to_datetime(df_train["Timestamp"]).dt.date
df_train["TIME"] = pd.to_datetime(df_train["Timestamp"]).dt.time

# %%
# add hours and minutes for ml models
df_train["HOURS"] = pd.to_datetime(df_train["TIME"], format='%H:%M:%S').dt.hour
df_train["MINUTES"] = pd.to_datetime(df_train["TIME"], format='%H:%M:%S').dt.minute

# %%
df_train["YEAR"] = pd.to_datetime(df_train["Timestamp"]).dt.year

# %%
df_train["DATE"] = df_train["DATE"].astype(str)
# df_train["HOURS"] = df_train["HOURS"].astype(str)
df_train["TIME"] = df_train["TIME"].astype(str)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210240 entries, 0 to 210239
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Timestamp           210240 non-null  object
#  1   Temperature         210240 non-null  float64
#  2   Dew Point           210240 non-null  float64
#  3   Surface Albedo      210240 non-null  float64
#  4   Pressure            210240 non-null  int64
#  5   Wind Direction      210240 non-null  int64
#  6   Wind Speed          210240 non-null  float64
#  7   Clearsky DHI        210240 non-null  int64
#  8   Clearsky DNI        210240 non-null  int64
#  9   Clearsky GHI        210240 non-null  int64
#  10  Fill Flag           210240 non-null  int64
#  11  Ozone               210240 non-null  float64
#  12  Cloud Type          210240 non-null  int64
#  13  Solar Zenith Angle  210240 non-null  float64
#  14  Precipitable Water  210240 non-null  float64
#  15  Relative Humidity   210240 non-null  float64
#  16  DAY                 210240 non-null  int32
#  17  MONTH               210240 non-null  int64
#  18  WEEK                210240 non-null  int64
#  19  DATE                210240 non-null  object
#  20  TIME                210240 non-null  object
#  21  HOURS               210240 non-null  int64
#  22  MINUTES             210240 non-null  int64
#  23  YEAR                210240 non-null  int64
# dtypes: float64(8), int32(1), int64(12), object(3)
# memory usage: 37.7+ MB

# %%
df_train
# Out:
#                  Timestamp  Temperature  Dew Point  Surface Albedo  Pressure  \
# 0      2019-01-01 00:00:00         12.5        6.9            0.21      1005
# 1      2019-01-01 00:10:00         12.3        6.9            0.21      1005
# 2      2019-01-01 00:20:00         12.1        6.9            0.21      1005
# 3      2019-01-01 00:30:00         12.0        6.9            0.21      1005
# 4      2019-01-01 00:40:00         11.8        6.9            0.21      1005
# ...                    ...          ...        ...             ...       ...
# 210235 2022-12-31 23:10:00          6.9        5.8            0.21      1009
# 210236 2022-12-31 23:20:00          6.8        5.8            0.21      1009
# 210237 2022-12-31 23:30:00          6.8        5.8            0.21      1009
# 210238 2022-12-31 23:40:00          6.8        5.6            0.21      1009
# 210239 2022-12-31 23:50:00          6.8        5.6            0.21      1009
#
#         Wind Direction  Wind Speed  Clearsky DHI  Clearsky DNI  Clearsky GHI  \
# 0                  121         1.0             0             0             0
# 1                  122         1.0             0             0             0
# 2                  124         1.0             0             0             0
# 3                  125         1.0             0             0             0
# 4                  126         1.0             0             0             0
# ...                ...         ...           ...           ...           ...
# 210235              54         1.2             0             0             0
# 210236              54         1.2             0             0             0
# 210237              55         1.1             0             0             0
# 210238              55         1.1             0             0             0
# 210239              56         1.1             0             0             0
#
#         ...  Relative Humidity  DAY  MONTH  WEEK        DATE      TIME  HOURS  \
# 0       ...              68.82    5      1     1  2019-01-01  00:00:00      0
# 1       ...              69.73    5      1     1  2019-01-01  00:10:00      0
# 2       ...              70.65    5      1     1  2019-01-01  00:20:00      0
# 3       ...              71.11    5      1     1  2019-01-01  00:30:00      0
# 4       ...              71.91    5      1     1  2019-01-01  00:40:00      0
# ...     ...                ...  ...    ...   ...         ...       ...    ...
# 210235  ...              92.63    2     12    52  2022-12-31  23:10:00     23
# 210236  ...              93.26    2     12    52  2022-12-31  23:20:00     23
# 210237  ...              93.26    2     12    52  2022-12-31  23:30:00     23
# 210238  ...              91.95    2     12    52  2022-12-31  23:40:00     23
# 210239  ...              91.95    2     12    52  2022-12-31  23:50:00     23
#
#         MINUTES  YEAR GHI_cal
# 0             0     0     0.0
# 1            10     0     0.0
# 2            20     0     0.0
# 3            30     0     0.0
# 4            40     0     0.0
# ...         ...   ...     ...
# 210235       10     3     0.0
# 210236       20     3     0.0
# 210237       30     3     0.0
# 210238       40     3     0.0
# 210239       50     3     0.0
#
# [210240 rows x 25 columns]

# %%
df_train.drop(columns = ['Fill Flag', 'Timestamp','TIME','DATE'], inplace=True)

# %%
df_train
# Out:
#         Temperature  Dew Point  Surface Albedo  Pressure  Wind Direction  \
# 0              12.5        6.9            0.21      1005             121
# 1              12.3        6.9            0.21      1005             122
# 2              12.1        6.9            0.21      1005             124
# 3              12.0        6.9            0.21      1005             125
# 4              11.8        6.9            0.21      1005             126
# ...             ...        ...             ...       ...             ...
# 210235          6.9        5.8            0.21      1009              54
# 210236          6.8        5.8            0.21      1009              54
# 210237          6.8        5.8            0.21      1009              55
# 210238          6.8        5.6            0.21      1009              55
# 210239          6.8        5.6            0.21      1009              56
#
#         Wind Speed  Clearsky DHI  Clearsky DNI  Clearsky GHI  Ozone  \
# 0              1.0             0             0             0  0.258
# 1              1.0             0             0             0  0.258
# 2              1.0             0             0             0  0.258
# 3              1.0             0             0             0  0.258
# 4              1.0             0             0             0  0.258
# ...            ...           ...           ...           ...    ...
# 210235         1.2             0             0             0  0.279
# 210236         1.2             0             0             0  0.279
# 210237         1.1             0             0             0  0.279
# 210238         1.1             0             0             0  0.279
# 210239         1.1             0             0             0  0.280
#
#         Cloud Type  Solar Zenith Angle  Precipitable Water  Relative Humidity  \
# 0                1              173.92                 1.4              68.82
# 1                1              171.79                 1.3              69.73
# 2                1              169.59                 1.3              70.65
# 3                1              167.37                 1.3              71.11
# 4                1              165.13                 1.3              71.91
# ...            ...                 ...                 ...                ...
# 210235           4              173.77                 1.8              92.63
# 210236           7              175.77                 1.8              93.26
# 210237           7              177.31                 1.8              93.26
# 210238           7              177.36                 1.8              91.95
# 210239           7              175.87                 1.8              91.95
#
#         DAY  MONTH  WEEK HOURS  MINUTES  YEAR
# 0         5      1     1     0        0  2019
# 1         5      1     1     0       10  2019
# 2         5      1     1     0       20  2019
# 3         5      1     1     0       30  2019
# 4         5      1     1     0       40  2019
# ...     ...    ...   ...   ...      ...   ...
# 210235    2     12    52    23       10  2022
# 210236    2     12    52    23       20  2022
# 210237    2     12    52    23       30  2022
# 210238    2     12    52    23       40  2022
# 210239    2     12    52    23       50  2022
#
# [210240 rows x 20 columns]

# %% [markdown]
# # Heatmap analysis

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(20,20))
plt.title('Pearson Correlation of Features')
sns.heatmap(df_train.corr(), square=True, cmap=colormap, annot=True)
# Out:
# <AxesSubplot:title={'center':'Pearson Correlation of Features'}>

# %%
df_train.shape
# Out:
# (210240, 21)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210240 entries, 0 to 210239
# Data columns (total 21 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Temperature         210240 non-null  float64
#  1   Dew Point           210240 non-null  float64
#  2   Surface Albedo      210240 non-null  float64
#  3   Pressure            210240 non-null  int64
#  4   Wind Direction      210240 non-null  int64
#  5   Wind Speed          210240 non-null  float64
#  6   Clearsky DHI        210240 non-null  int64
#  7   Clearsky DNI        210240 non-null  int64
#  8   Clearsky GHI        210240 non-null  int64
#  9   Ozone               210240 non-null  float64
#  10  Cloud Type          210240 non-null  int64
#  11  Solar Zenith Angle  210240 non-null  float64
#  12  Precipitable Water  210240 non-null  float64
#  13  Relative Humidity   210240 non-null  float64
#  14  DAY                 210240 non-null  int32
#  15  MONTH               210240 non-null  int64
#  16  WEEK                210240 non-null  int64
#  17  HOURS               210240 non-null  object
#  18  MINUTES             210240 non-null  int64
#  19  YEAR                210240 non-null  int64
#  20  DATE_STRING         210240 non-null  object
# dtypes: float64(8), int32(1), int64(10), object(2)
# memory usage: 32.9+ MB

# %% [markdown]
# # Model Selection

# %%
from xgboost import XGBRegressor

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
X = df_train.drop(columns=['Clearsky GHI'])
y = df_train['Clearsky GHI']

# %%
X1 = df_train.drop(columns=['Clearsky GHI','Clearsky DHI','Clearsky DNI'])
y1 = df_train['Clearsky GHI']

X2 = df_train.drop(columns=['Clearsky GHI','Clearsky DHI','Clearsky DNI'])
y2 = df_train['Clearsky DHI']

X3 = df_train.drop(columns=['Clearsky GHI','Clearsky DHI','Clearsky DNI'])
y3 = df_train['Clearsky DNI']

# %% [markdown]
# # Train-validation split

# %%
x1_train, x1_valid, y1_train, y1_valid = train_test_split(X1, y1, test_size=0.10, random_state=101)

x2_train, x2_valid, y2_train, y2_valid = train_test_split(X2, y2, test_size=0.10, random_state=101)

x3_train, x3_valid, y3_train, y3_valid = train_test_split(X3, y3, test_size=0.10, random_state=101)

# %% [markdown]
# # Model fitting

# %%
model1 = XGBRegressor(learning_rate = 0.4, max_depth = 9, n_estimators = 1000, reg_alpha = 0)
model1.fit(x1_train, y1_train)#GHI

model2 = XGBRegressor(learning_rate = 0.4, max_depth = 9, n_estimators = 1000, reg_alpha = 0)
model2.fit(x2_train, y2_train)#DHI

model3 = XGBRegressor(learning_rate = 0.4, max_depth = 9, n_estimators = 1000, reg_alpha = 0)
model3.fit(x3_train, y3_train)#DNI
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [52], in <cell line: 2>()
#       1 model1 = XGBRegressor(learning_rate = 0.4, max_depth = 9, n_estimators = 1000, reg_alpha = 0)
# ----> 2 model1.fit(x1_train, y1_train)#GHI
#       4 model2 = XGBRegressor(learning_rate = 0.4, max_depth = 9, n_estimators = 1000, reg_alpha = 0)
#       5 model2.fit(x2_train, y2_train)#DHI
#
# File ~\Anaconda3\lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~\Anaconda3\lib\site-packages\xgboost\sklearn.py:988, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#     986 with config_context(verbosity=self.verbosity):
#     987     evals_result: TrainingCallback.EvalsLog = {}
# --> 988     train_dmatrix, evals = _wrap_evaluation_matrices(
#     989         missing=self.missing,
#     990         X=X,
#     991         y=y,
#     992         group=None,
#     993         qid=None,
#     994         sample_weight=sample_weight,
#     995         base_margin=base_margin,
#     996         feature_weights=feature_weights,
#     997         eval_set=eval_set,
#     998         sample_weight_eval_set=sample_weight_eval_set,
#     999         base_margin_eval_set=base_margin_eval_set,
#    1000         eval_group=None,
#    1001         eval_qid=None,
#    1002         create_dmatrix=self._create_dmatrix,
#    1003         enable_categorical=self.enable_categorical,
#    1004         feature_types=self.feature_types,
#    1005     )
#    1006     params = self.get_xgb_params()
#    1008     if callable(self.objective):
#
# File ~\Anaconda3\lib\site-packages\xgboost\sklearn.py:448, in _wrap_evaluation_matrices(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical, feature_types)
#     428 def _wrap_evaluation_matrices(
#     429     missing: float,
#     430     X: Any,
#    (...)
#     444     feature_types: Optional[FeatureTypes],
#     445 ) -> Tuple[Any, List[Tuple[Any, str]]]:
#     446     """Convert array_like evaluation matrices into DMatrix.  Perform validation on the
#     447     way."""
# --> 448     train_dmatrix = create_dmatrix(
#     449         data=X,
#     450         label=y,
#     451         group=group,
#     452         qid=qid,
#     453         weight=sample_weight,
#     454         base_margin=base_margin,
#     455         feature_weights=feature_weights,
#     456         missing=missing,
#     457         enable_categorical=enable_categorical,
#     458         feature_types=feature_types,
#     459         ref=None,
#     460     )
#     462     n_validation = 0 if eval_set is None else len(eval_set)
#     464     def validate_or_none(meta: Optional[Sequence], name: str) -> Sequence:
#
# File ~\Anaconda3\lib\site-packages\xgboost\sklearn.py:908, in XGBModel._create_dmatrix(self, ref, **kwargs)
#     906     except TypeError:  # `QuantileDMatrix` supports lesser types than DMatrix
#     907         pass
# --> 908 return DMatrix(**kwargs, nthread=self.n_jobs)
#
# File ~\Anaconda3\lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~\Anaconda3\lib\site-packages\xgboost\core.py:743, in DMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical)
#     740     assert self.handle is not None
#     741     return
# --> 743 handle, feature_names, feature_types = dispatch_data_backend(
#     744     data,
#     745     missing=self.missing,
#     746     threads=self.nthread,
#     747     feature_names=feature_names,
#     748     feature_types=feature_types,
#     749     enable_categorical=enable_categorical,
#     750 )
#     751 assert handle is not None
#     752 self.handle = handle
#
# File ~\Anaconda3\lib\site-packages\xgboost\data.py:970, in dispatch_data_backend(data, missing, threads, feature_names, feature_types, enable_categorical)
#     968     return _from_tuple(data, missing, threads, feature_names, feature_types)
#     969 if _is_pandas_df(data):
# --> 970     return _from_pandas_df(data, enable_categorical, missing, threads,
#     971                            feature_names, feature_types)
#     972 if _is_pandas_series(data):
#     973     return _from_pandas_series(
#     974         data, missing, threads, enable_categorical, feature_names, feature_types
#     975     )
#
# File ~\Anaconda3\lib\site-packages\xgboost\data.py:417, in _from_pandas_df(data, enable_categorical, missing, nthread, feature_names, feature_types)
#     409 def _from_pandas_df(
#     410     data: DataFrame,
#     411     enable_categorical: bool,
#    (...)
#     415     feature_types: Optional[FeatureTypes],
#     416 ) -> DispatchedDataBackendReturnType:
# --> 417     data, feature_names, feature_types = _transform_pandas_df(
#     418         data, enable_categorical, feature_names, feature_types
#     419     )
#     420     return _from_numpy_array(data, missing, nthread, feature_names, feature_types)
#
# File ~\Anaconda3\lib\site-packages\xgboost\data.py:391, in _transform_pandas_df(data, enable_categorical, feature_names, feature_types, meta, meta_type)
#     379 from pandas.api.types import (
#     380     is_sparse,
#     381     is_categorical_dtype,
#     382 )
#     384 if not all(
#     385     dtype.name in _pandas_dtype_mapper
#     386     or is_sparse(dtype)
#    (...)
#     389     for dtype in data.dtypes
#     390 ):
# --> 391     _invalid_dataframe_dtype(data)
#     393 feature_names, feature_types = _pandas_feature_info(
#     394     data, meta, feature_names, feature_types, enable_categorical
#     395 )
#     397 transformed = _pandas_cat_null(data)
#
# File ~\Anaconda3\lib\site-packages\xgboost\data.py:283, in _invalid_dataframe_dtype(data)
#     281 type_err = "DataFrame.dtypes for data must be int, float, bool or category."
#     282 msg = f"""{type_err} {_ENABLE_CAT_ERR} {err}"""
# --> 283 raise ValueError(msg)
#
# ValueError: DataFrame.dtypes for data must be int, float, bool or category. When categorical type is supplied, The experimental DMatrix parameter`enable_categorical` must be set to `True`.  Invalid columns:HOURS: object

# %% [markdown]
# # Predction and evaluation

# %%
train_pred1 = model1.predict(x1_train)
valid_pred1 = model1.predict(x1_valid)

# %%
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import r2_score

# %%
print('Clearsky GHI')
print(f"Train score = {model1.score(x1_train, y1_train)}\tTrain MSE = {mean_squared_error(train1_pred, y1_train)}")
print(f"Validation score = {model1.score(x1_valid, y1_valid)}\tValidation MSE = {mean_squared_error(valid1_pred, y1_valid)}")
# Out:
# Clearsky GHI
# Train score = 0.9999987491497198	Train MSE = 0.13216762497854825
# Validation score = 0.9998256770364767	Validation MSE = 18.409877324993758

# %%
print(model1.score(x1_train, y1_train),r2_score(y1_train,train_pred))
# Out:
# 0.9999987491497198 0.9999987491497198

# %%
rmse1 = np.sqrt(MSE(train_pred,y1_train))

# %%
rmse1
# Out:
# 0.36354865558622035

# %%
train2_pred = model2.predict(x2_train)
valid2_pred = model2.predict(x2_valid)

# %%
print('Clearsky DHI')
print(f"Train score = {model2.score(x2_train, y2_train)}\tTrain MSE = {mean_squared_error(train2_pred, y2_train)}")
print(f"Validation score = {model2.score(x2_valid, y2_valid)}\tValidation MSE = {mean_squared_error(valid2_pred, y2_valid)}")
# Out:
# Clearsky DHI
# Train score = 0.9999777656535319	Train MSE = 0.32209105784283143
# Validation score = 0.9963266238819665	Validation MSE = 52.99630787279874

# %%
train3_pred = model3.predict(x3_train)
valid3_pred = model3.predict(x3_valid)

# %%
print('Clearsky DNI')
print(f"Train score = {model3.score(x3_train, y3_train)}\tTrain MSE = {mean_squared_error(train3_pred, y3_train)}")
print(f"Validation score = {model3.score(x3_valid, y3_valid)}\tValidation MSE = {mean_squared_error(valid3_pred, y3_valid)}")
# Out:
# Clearsky DNI
# Train score = 0.9999696118128034	Train MSE = 2.3462089450513046
# Validation score = 0.9964933589280701	Validation MSE = 271.83921762782353

# %% [markdown]
# # Test Set

# %%
test_data_path = "C:\\Users\\Saranya.Sakkarapani\\solar_data\\test_data\\test.csv"
df_test = pd.read_csv(test_data_path)

# %%
df_test['Timestamp'] = pd.to_datetime(df_test['Timestamp'], format='%Y-%m-%d %H:%M:%S')

# %%
df_test["DAY"] = pd.to_datetime(df_test["Timestamp"]).dt.day_name()
df_test["MONTH"] = pd.to_datetime(df_test["Timestamp"]).dt.month
df_test["WEEK"] = pd.to_datetime(df_test["Timestamp"]).dt.week
# Out:
# C:\Users\Saranya.Sakkarapani\AppData\Local\Temp\ipykernel_11140\1345873206.py:3: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df_test["WEEK"] = pd.to_datetime(df_test["Timestamp"]).dt.week

# %%
from sklearn import preprocessing
  
# label_encoder object knows 
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'day'.
df_test['DAY']= label_encoder.fit_transform(df_test['DAY'])
  
df_test['DAY'].unique()
# Out:
# array([3, 1, 5, 6, 4, 0, 2])

# %%
df_test["DATE"] = pd.to_datetime(df_test["Timestamp"]).dt.date
df_test["TIME"] = pd.to_datetime(df_test["Timestamp"]).dt.time

# %%
# add hours and minutes for ml models
df_test["HOURS"] = pd.to_datetime(df_test["TIME"], format='%H:%M:%S').dt.hour
df_test["MINUTES"] = pd.to_datetime(df_test["TIME"], format='%H:%M:%S').dt.minute

# %%
df_test["YEAR"] = pd.to_datetime(df_test["Timestamp"]).dt.year

# %%
df_test['YEAR'].unique()
# Out:
# array([2023], dtype=int64)

# %%
# Encode labels in column 'day'.
df_test['YEAR']= label_encoder.fit_transform(df_test['YEAR'])
df_test['YEAR'].unique()
# Out:
# array([0], dtype=int64)

# %%
df_test.drop(columns = ['Fill Flag', 'Timestamp','TIME','DATE'], inplace=True)

# %%
X_test = df_test.drop(columns=['Clearsky GHI','Clearsky DHI','Clearsky DNI'])

# %%
X_test
# Out:
#        Temperature  Dew Point  Surface Albedo  Pressure  Wind Direction  \
# 0             11.3        1.6            0.21      1006             305
# 1             11.2        1.6            0.21      1006             306
# 2             11.1        1.6            0.21      1006             306
# 3             11.0        1.6            0.21      1006             307
# 4             10.9        1.2            0.21      1006             307
# ...            ...        ...             ...       ...             ...
# 52555         11.7        2.0            0.21      1006             303
# 52556         11.6        2.0            0.21      1006             303
# 52557         11.5        2.0            0.21      1006             304
# 52558         11.4        1.6            0.21      1006             304
# 52559         11.3        1.6            0.21      1006             305
#
#        Wind Speed  Ozone  Cloud Type  Solar Zenith Angle  Precipitable Water  \
# 0             1.2  0.255           0              173.92                 1.4
# 1             1.2  0.255           0              171.79                 1.4
# 2             1.2  0.255           0              169.59                 1.4
# 3             1.2  0.255           0              167.37                 1.4
# 4             1.2  0.255           0              165.13                 1.4
# ...           ...    ...         ...                 ...                 ...
# 52555         1.2  0.254           0              173.67                 1.4
# 52556         1.2  0.254           0              175.68                 1.4
# 52557         1.2  0.254           0              177.23                 1.4
# 52558         1.2  0.254           0              177.34                 1.4
# 52559         1.2  0.254           0              175.90                 1.4
#
#        Relative Humidity  DAY  MONTH  WEEK  HOURS  MINUTES  YEAR
# 0                  51.38    3      1    52      0        0     0
# 1                  51.72    3      1    52      0       10     0
# 2                  52.06    3      1    52      0       20     0
# 3                  52.41    3      1    52      0       30     0
# 4                  51.34    3      1    52      0       40     0
# ...                  ...  ...    ...   ...    ...      ...   ...
# 52555              51.26    3     12    52     23       10     0
# 52556              51.60    3     12    52     23       20     0
# 52557              51.94    3     12    52     23       30     0
# 52558              51.04    3     12    52     23       40     0
# 52559              51.38    3     12    52     23       50     0
#
# [52560 rows x 17 columns]

# %%
pred3 = model3.predict(X_test)#DNI

# %%
pred3
# Out:
# array([-12.085325 ,  -8.564141 ,  -8.619026 , ...,   1.9697886,
#          1.7565507,   1.1787112], dtype=float32)

# %%
pred2 = model2.predict(X_test)#DHI

# %%
pred2
# Out:
# array([-0.8792654 , -0.84820676, -0.7449561 , ..., -0.19277784,
#        -0.27534097,  0.14917006], dtype=float32)

# %%
pred1 = pred3*np.cos(np.radians(df_test['Solar Zenith Angle'])) + pred2  #GHI

# %%
pred1
# Out:
# 0        11.138080
# 1         7.628163
# 2         7.732200
# 3         2.173273
# 4         3.728998
#            ...
# 52555    -1.889668
# 52556    -2.173334
# 52557    -2.160265
# 52558    -2.029999
# 52559    -1.026525
# Name: Solar Zenith Angle, Length: 52560, dtype: float64

# %%
subm = pd.DataFrame()
subm['Clearsky GHI'] = pred1
subm['Clearsky DHI'] = pred2
subm['Clearsky DNI'] = pred3

# %%
# subm.loc[ subm['Clearsky DHI'] < 0, 'Clearksy DHI'] = 0
subm.loc[ subm['Clearsky DNI'] < 0, 'Clearsky DNI'] = 0
subm.loc[ subm['Clearsky GHI'] < 0, 'Clearsky GHI'] = 0
subm['Clearsky DHI'] = subm['Clearsky DHI'].astype("int")
subm['Clearsky DNI'] = subm['Clearsky DNI'].astype("int")
subm['Clearsky GHI'] = subm['Clearsky GHI'].astype("int")

# %%
subm.head()
# Out:
#    Clearsky GHI  Clearsky DHI  Clearsky DNI
# 0            11             0             0
# 1             7             0             0
# 2             7             0             0
# 3             2             0             0
# 4             3             0             0

# %%
subm.tail()
# Out:
#        Clearsky GHI  Clearsky DHI  Clearsky DNI
# 52555             0             0             1
# 52556             0             0             2
# 52557             0             0             1
# 52558             0             0             1
# 52559             0             0             1

# %%
subm.to_csv('solar_submission.csv', index=False)
